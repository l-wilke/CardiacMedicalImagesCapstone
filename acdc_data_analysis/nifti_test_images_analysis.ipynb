# %%
#Verifying if the test data or post test data had contours
#Reason: if yes to augment the training data for unet
#Findings: No the contours were missing
import nibabel as nib
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
nif_image='/masvol/data/acdc/post_testing/testing/patient101/patient101_4d.nii.gz'
nif_image_i=nib.load(nif_image)
nif_image_i.shape
# Out:
# (232, 256, 10, 30)

# %%
nif_label_01='/masvol/data/acdc/post_testing/testing/patient101/patient101_frame01.nii.gz'
nif_label_01_i=nib.load(nif_label_01)
nif_label_01_i.shape
# Out:
# (232, 256, 10)

# %%
nif_label_14='/masvol/data/acdc/post_testing/testing/patient101/patient101_frame14.nii.gz'
nif_label_14_i=nib.load(nif_label_14)
nif_label_14_i.shape
# Out:
# (232, 256, 10)

# %%
plt.imshow(nif_image_i.get_data()[:,:,1,0], cmap="bone")

# %%
plt.imshow(nif_label_01_i.get_data()[:,:,2], cmap="bone")

# %%
for i in nif_image.shape[2]:
    f, axs = plt.subplots(1,2,figsize=(15,15))
    plt.subplot(121),plt.imshow(nif_image[i].reshape(x, y))
    #plt.title('test image {0} size:{1}'.format(image_array[i],ones))
    plt.xticks([]), plt.yticks([])

# %%
cfg='/masvol/data/acdc/post_testing/testing/patient101/Info.cfg'
# !cat /masvol/data/acdc/post_testing/testing/patient101/Info.cfg
# Out:
# ED: 1
# ES: 14
# Height: 169.0
# NbFrame: 30
# Weight: 79.0

# %%
old_data='/masvol/data/acdc/niftidata/patient001/labels/patient001_slice10_frame12_label.nii'

label=nib.load(old_data)
print(label.shape)
plt.imshow(label.get_data(), cmap="bone")
# Out:
# (216, 256)

# %%
nif_image='/masvol/data/acdc/testing/testing/patient101/patient101_4d.nii.gz'
nif_image_i=nib.load(nif_image)
nif_image_i.shape
# Out:
# (232, 256, 10, 30)

# %%
nif_label_01='/masvol/data/acdc/testing/testing/patient101/patient101_frame01.nii.gz'
nif_label_01_i=nib.load(nif_label_01)
nif_label_01_i.shape
# Out:
# (232, 256, 10)

# %%
plt.imshow(nif_image_i.get_data()[:,:,3,0], cmap="bone")

# %%
plt.imshow(nif_label_01_i.get_data()[:,:,3], cmap="bone")

# %%
nif_label_14='/masvol/data/acdc/testing/testing/patient101/patient101_frame14.nii.gz'
nif_label_14_i=nib.load(nif_label_14)
nif_label_14_i.shape
# Out:
# (232, 256, 10)

# %%
plt.imshow(nif_label_14_i.get_data()[:,:,3], cmap="bone")
